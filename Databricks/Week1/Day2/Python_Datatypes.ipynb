# %% [markdown]
# # Python Data Types

# %% [markdown]
# ## Numbers

# %%
total_sales = 125000
tax_rate = 0.18
tax_amount = total_sales * tax_rate
total_sales, tax_amount
type(total_sales)
# Out:
# int

# %% [markdown]
# ## Strings

# %%
customer_name = "Kumar"
email = "kumar@gmail.com"
customer_name, email

# %% [markdown]
# ## Lists

# %%
order_ids = [101, 102, 103]
order_ids.append(104)
order_ids

# %% [markdown]
# ## Tuples

# %%
db_config = ("sqlserver", 1433, "SalesDB")
db_config

# %% [markdown]
# ## Sets

# %%
cities = {"Bangalore", "Chennai", "Bangalore"}
cities
a=set()
a
# Out:
# set()

# %% [markdown]
# ## Dictionaries

# %%
customer = {"id": 1, "name": "Raj", "active": True}
customer

# %% [markdown]
# ## Boolean

# %%
is_high_value = total_sales > 100000
is_high_value
# Out:
# True

# %% [markdown]
# ## Range

# %%
for i in range(3):
    print("Retry", i+1)

# %% [markdown]
# ## Casting

# %%
price = "1500"
price_int = int(price)
price_int

# %% [markdown]
# ## Binary Type

# %%
data = bytes(5)
type(data)
data
# Out:
# b'\x00\x00\x00\x00\x00'

# %% [markdown]
# ## NoneType

# %%
phone = None
phone
